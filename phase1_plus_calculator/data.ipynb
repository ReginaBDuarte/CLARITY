# %%
import pandas as pd

# %%
data=pd.read_csv('results_phase1_plus_calculator.csv')
data.Score2.to_list()
# Out:
# ['1.67',
#  '1.58',
#  '3.1',
#  '3.44',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  '5.0',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  '9.41',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  '5.61',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable',
#  'SCORE2 not applicable']
